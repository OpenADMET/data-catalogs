# %%
import openadmet.toolkit.database.process_utils as prut

# %% [markdown]
# # WARNING
#
# Be sure to check your processed structures visually upon completion.
#
# Some PDB cleaning needs to be done by hand. This is case based. While the below function might apply all necessary filters to most PDB files, it is important to check your final files visually. For example, CYP3A4 6daj has a floating GLN group that, after download and processing with this code, had to still be removed by hand.

# %%
#load cif files and process
target='CYP3A4'
outdir = 'process_cif_test'
input_path = 'cif_test'

prut.process_rcsb_pdb(target, input_path=input_path, outdir=outdir)
# Out:
# Processing: 9BV6
# Checking Chain IDs...
# Saved processed file: process_cif_test/9BV6_cleaned.cif
#
# Processing: 6OOB
# Checking Chain IDs...
# Saved processed file: process_cif_test/6OOB_cleaned.cif
#
# Processing: 6BDH
# Checking Chain IDs...
# Saved processed file: process_cif_test/6BDH_cleaned.cif
#
# Processing: 6BDI
# Checking Chain IDs...
# Saved processed file: process_cif_test/6BDI_cleaned.cif
#
# Processing: 2V0M
# Checking Chain IDs...
# Saved processed file: process_cif_test/2V0M_cleaned.cif
#
# Processing: 7KSA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 outdir = 'process_cif_test'
#       4 input_path = 'cif_test'
# ----> 6 prut.process_rcsb_pdb(target, input_path=input_path, outdir=outdir)
#
# File ~/Documents/Work/openadmet/openadmet-toolkit/openadmet/toolkit/database/process_utils.py:82, in process_rcsb_pdb(target, input_path, fmt, outdir)
#      80 final_path = f"{outdir}/{_id}_cleaned.{fmt}"
#      81 entry = get_rcsb_data_entry(_id)
# ---> 82 chain_ids = get_chain_ids(entry, _id, rut.UNIPROT_IDS[target])
#      83 print(f"Checking Chain IDs...")
#      84 if 'A' not in chain_ids:
#
# File ~/Documents/Work/openadmet/openadmet-toolkit/openadmet/toolkit/database/process_utils.py:61, in get_chain_ids(entry, pdb_id, uniprot)
#      59 chains = []
#      60 for ent in entities:
# ---> 61     r2 = requests.get(
#      62         f"https://data.rcsb.org/rest/v1/core/polymer_entity/{pdb_id}/{ent}"
#      63     )
#      64     if r2.status_code != 200:
#      65         continue
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/urllib3/response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1047 """
#    1048 A generator wrapper for the read() method. A call will block until
#    1049 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1060     'content-encoding' header.
#    1061 """
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/urllib3/response.py:1222, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1220 if self.chunk_left == 0:
#    1221     break
# -> 1222 chunk = self._handle_chunk(amt)
#    1223 decoded = self._decode(
#    1224     chunk, decode_content=decode_content, flush_decoder=False
#    1225 )
#    1226 if decoded:
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/site-packages/urllib3/response.py:1169, in HTTPResponse._handle_chunk(self, amt)
#    1167 else:  # amt > self.chunk_left
#    1168     returned_chunk = self._fp._safe_read(self.chunk_left)  # type: ignore[union-attr]
# -> 1169     self._fp._safe_read(2)  # type: ignore[union-attr] # Toss the CRLF at the end of the chunk.
#    1170     self.chunk_left = None
#    1171 return returned_chunk
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/http/client.py:642, in HTTPResponse._safe_read(self, amt)
#     635 def _safe_read(self, amt):
#     636     """Read the number of bytes requested.
#     637
#     638     This function should be used when <amt> bytes "should" be present for
#     639     reading. If the bytes are truly not available (due to EOF), then the
#     640     IncompleteRead exception can be used to detect the problem.
#     641     """
# --> 642     data = self.fp.read(amt)
#     643     if len(data) < amt:
#     644         raise IncompleteRead(data, amt-len(data))
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/oadmet-gen/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#load pdb files and process
target='CYP3A4'
outdir = 'process_pdb_test'
input_path = 'pdb_test'

process_rcsb_pdb(target, input_path=input_path, fmt='pdb',  outdir=outdir)
