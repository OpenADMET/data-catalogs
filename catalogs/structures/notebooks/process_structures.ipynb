# %%
import openadmet.toolkit.database.process_utils as prut

# %% [markdown]
# # WARNING
#
# Be sure to check your processed structures visually upon completion.
#
# Some PDB cleaning needs to be done by hand. This is case based. While the below function might apply all necessary filters to most PDB files, it is important to check your final files visually.
#
# For example, CYP3A4 6DAJ has a floating GLN group that, after download and processing with this code, had to still be removed by hand.

# %%
#load cif files and process
target='PXR'
outdir = 'example_output/cif_process_test/'
input_path = 'example_output/cif_download_test/'

prut.process_rcsb_pdb(target, input_path=input_path, outdir=outdir)
# Out:
# Processing: 9FZG
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/9FZG_cleaned.cif
#
# Processing: 7RIO
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/7RIO_cleaned.cif
#
# Processing: 1ILG
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/1ILG_cleaned.cif
#
# Processing: 8R82
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/8R82_cleaned.cif
#
# Processing: 2QNV
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/2QNV_cleaned.cif
#
# Processing: 8R81
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/8R81_cleaned.cif
#
# Processing: 5A86
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/5A86_cleaned.cif
#
# Processing: 7YFK
# Checking Chain IDs...
# Saved processed file: example_output/cif_process_test/7YFK_cleaned.cif
#
# Processing: 6S41
# Checking Chain IDs...
# ...

# %%
#load pdb files and process
target='PXR'
outdir = 'example_output/pdb_process_test/'
input_path = 'example_output/pdb_download_test/'

prut.process_rcsb_pdb(target, input_path=input_path, fmt='pdb',  outdir=outdir)
# Out:
# Processing: 9FZG
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/9FZG_cleaned.pdb
#
# Processing: 7RIO
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/7RIO_cleaned.pdb
#
# Processing: 2QNV
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/2QNV_cleaned.pdb
#
# Processing: 1ILG
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/1ILG_cleaned.pdb
#
# Processing: 8R82
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/8R82_cleaned.pdb
#
# Processing: 8R81
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/8R81_cleaned.pdb
#
# Processing: 6XP9
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/6XP9_cleaned.pdb
#
# Processing: 7AX8
# Checking Chain IDs...
# Saved processed file: example_output/pdb_process_test/7AX8_cleaned.pdb
#
# Processing: 7AX9
# Checking Chain IDs...
# ...
