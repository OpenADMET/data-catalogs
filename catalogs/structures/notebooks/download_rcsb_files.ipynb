# %%
from openadmet.toolkit.database import rcsb_utils as rut

# %% [markdown]
# This file downloads and saves raw files from [RCSB PDB](https://www.rcsb.org/) using functions available in [openadmet-toolkit](https://github.com/OpenADMET/openadmet-toolkit).
#
# # Query PDB IDs
#
# To start define your target of interest. This target should match a key in the internal dictionary UNIPROT_IDs. If you already have the Uniprot ID for your target, this can act as input into the query function below, get_pdb_ids.

# %%
rut.UNIPROT_IDS.keys()
# Out:
# dict_keys(['CYP2D6', 'CYP3A4', 'CYP1A2', 'CYP2C9', 'PXR', 'AHR'])

# %%
target = "CYP3A4"

# %%
pdb_ids = rut.get_pdb_ids(rut.UNIPROT_IDS[target])
# Out:
# Found 122 PDB IDs.

# %% [markdown]
# The available functionality allows for downloading mmCIF or PDB file types. The code is defaulted for the cif format, as pdb is depricated. If you are interested in PDB files, however, conversion code from mmCIF to PDB is available for newer files that do not have a PDB file associated.
# An example for both downloading mmCIF and PDB are shown below.

# %%
# Download mmCIF

output = 'cif_test'
for _id in pdb_ids:
    pdb_response = rut.get_rcsb_url(_id)
    pdb_text = rut.download_rcsb_file(_id, outdir=output)
# Out:
# Downloading 1TQN from RCSB...
# Saving 1TQN from RCSB...
# Downloading 1W0E from RCSB...
# Saving 1W0E from RCSB...
# Downloading 1W0F from RCSB...
# Saving 1W0F from RCSB...
# Downloading 1W0G from RCSB...
# Saving 1W0G from RCSB...
# Downloading 2J0D from RCSB...
# Saving 2J0D from RCSB...
# Downloading 2V0M from RCSB...
# Saving 2V0M from RCSB...
# Downloading 3NXU from RCSB...
# Saving 3NXU from RCSB...
# Downloading 3TJS from RCSB...
# Saving 3TJS from RCSB...
# Downloading 3UA1 from RCSB...
# Saving 3UA1 from RCSB...
# Downloading 4D6Z from RCSB...
# Saving 4D6Z from RCSB...
# Downloading 4D75 from RCSB...
# Saving 4D75 from RCSB...
# Downloading 4D78 from RCSB...
# Saving 4D78 from RCSB...
# Downloading 4D7D from RCSB...
# Saving 4D7D from RCSB...
# Downloading 4I3Q from RCSB...
# Saving 4I3Q from RCSB...
# Downloading 4I4G from RCSB...
# Saving 4I4G from RCSB...
# Downloading 4I4H from RCSB...
# Saving 4I4H from RCSB...
# Downloading 4K9T from RCSB...
# Saving 4K9T from RCSB...
# Downloading 4K9U from RCSB...
# Saving 4K9U from RCSB...
# Downloading 4K9V from RCSB...
# Saving 4K9V from RCSB...
# Downloading 4K9W from RCSB...
# Saving 4K9W from RCSB...
# Downloading 4K9X from RCSB...
# Saving 4K9X from RCSB...
# Downloading 4NY4 from RCSB...
# Saving 4NY4 from RCSB...
# Downloading 5A1P from RCSB...
# Saving 5A1P from RCSB...
# Downloading 5A1R from RCSB...
# Saving 5A1R from RCSB...
# Downloading 5G5J from RCSB...
# Saving 5G5J from RCSB...
# Downloading 5TE8 from RCSB...
# Saving 5TE8 from RCSB...
# Downloading 5VC0 from RCSB...
# Saving 5VC0 from RCSB...
# Downloading 5VCC from RCSB...
# Saving 5VCC from RCSB...
# Downloading 5VCD from RCSB...
# Saving 5VCD from RCSB...
# Downloading 5VCE from RCSB...
# Saving 5VCE from RCSB...
# Downloading 5VCG from RCSB...
# Saving 5VCG from RCSB...
# Downloading 6BCZ from RCSB...
# Saving 6BCZ from RCSB...
# Downloading 6BD5 from RCSB...
# Saving 6BD5 from RCSB...
# Downloading 6BD6 from RCSB...
# Saving 6BD6 from RCSB...
# Downloading 6BD7 from RCSB...
# Saving 6BD7 from RCSB...
# Downloading 6BD8 from RCSB...
# Saving 6BD8 from RCSB...
# Downloading 6BDH from RCSB...
# Saving 6BDH from RCSB...
# Downloading 6BDI from RCSB...
# Saving 6BDI from RCSB...
# Downloading 6BDK from RCSB...
# Saving 6BDK from RCSB...
# Downloading 6BDM from RCSB...
# Saving 6BDM from RCSB...
# Downloading 6DA2 from RCSB...
# Saving 6DA2 from RCSB...
# Downloading 6DA3 from RCSB...
# Saving 6DA3 from RCSB...
# Downloading 6DA5 from RCSB...
# Saving 6DA5 from RCSB...
# Downloading 6DA8 from RCSB...
# Saving 6DA8 from RCSB...
# Downloading 6DAA from RCSB...
# Saving 6DAA from RCSB...
# Downloading 6DAB from RCSB...
# Saving 6DAB from RCSB...
# Downloading 6DAC from RCSB...
# Saving 6DAC from RCSB...
# Downloading 6DAG from RCSB...
# Saving 6DAG from RCSB...
# Downloading 6DAJ from RCSB...
# Saving 6DAJ from RCSB...
# Downloading 6DAL from RCSB...
# Saving 6DAL from RCSB...
# Downloading 6MA6 from RCSB...
# Saving 6MA6 from RCSB...
# Downloading 6MA7 from RCSB...
# Saving 6MA7 from RCSB...
# Downloading 6MA8 from RCSB...
# Saving 6MA8 from RCSB...
# Downloading 6OO9 from RCSB...
# Saving 6OO9 from RCSB...
# Downloading 6OOA from RCSB...
# Saving 6OOA from RCSB...
# Downloading 6OOB from RCSB...
# Saving 6OOB from RCSB...
# Downloading 6UNE from RCSB...
# Saving 6UNE from RCSB...
# Downloading 6UNG from RCSB...
# Saving 6UNG from RCSB...
# Downloading 6UNH from RCSB...
# Saving 6UNH from RCSB...
# Downloading 6UNI from RCSB...
# Saving 6UNI from RCSB...
# Downloading 6UNJ from RCSB...
# Saving 6UNJ from RCSB...
# Downloading 6UNK from RCSB...
# Saving 6UNK from RCSB...
# Downloading 6UNL from RCSB...
# Saving 6UNL from RCSB...
# Downloading 6UNM from RCSB...
# Saving 6UNM from RCSB...
# Downloading 7KS8 from RCSB...
# Saving 7KS8 from RCSB...
# Downloading 7KSA from RCSB...
# Saving 7KSA from RCSB...
# Downloading 7KVH from RCSB...
# Saving 7KVH from RCSB...
# Downloading 7KVI from RCSB...
# Saving 7KVI from RCSB...
# Downloading 7KVJ from RCSB...
# Saving 7KVJ from RCSB...
# Downloading 7KVK from RCSB...
# Saving 7KVK from RCSB...
# Downloading 7KVM from RCSB...
# Saving 7KVM from RCSB...
# Downloading 7KVN from RCSB...
# Saving 7KVN from RCSB...
# Downloading 7KVO from RCSB...
# Saving 7KVO from RCSB...
# Downloading 7KVP from RCSB...
# Saving 7KVP from RCSB...
# Downloading 7KVQ from RCSB...
# Saving 7KVQ from RCSB...
# Downloading 7KVS from RCSB...
# Saving 7KVS from RCSB...
# Downloading 7LXL from RCSB...
# Saving 7LXL from RCSB...
# Downloading 7UAY from RCSB...
# Saving 7UAY from RCSB...
# Downloading 7UAZ from RCSB...
# Saving 7UAZ from RCSB...
# Downloading 7UF9 from RCSB...
# Saving 7UF9 from RCSB...
# Downloading 7UFA from RCSB...
# Saving 7UFA from RCSB...
# Downloading 7UFB from RCSB...
# Saving 7UFB from RCSB...
# Downloading 7UFC from RCSB...
# Saving 7UFC from RCSB...
# Downloading 7UFD from RCSB...
# Saving 7UFD from RCSB...
# Downloading 7UFE from RCSB...
# Saving 7UFE from RCSB...
# Downloading 7UFF from RCSB...
# Saving 7UFF from RCSB...
# Downloading 8DYC from RCSB...
# Saving 8DYC from RCSB...
# Downloading 8EWD from RCSB...
# Saving 8EWD from RCSB...
# Downloading 8EWE from RCSB...
# Saving 8EWE from RCSB...
# Downloading 8EWL from RCSB...
# Saving 8EWL from RCSB...
# Downloading 8EWM from RCSB...
# Saving 8EWM from RCSB...
# Downloading 8EWN from RCSB...
# Saving 8EWN from RCSB...
# Downloading 8EWP from RCSB...
# Saving 8EWP from RCSB...
# Downloading 8EWQ from RCSB...
# Saving 8EWQ from RCSB...
# Downloading 8EWR from RCSB...
# Saving 8EWR from RCSB...
# Downloading 8EWS from RCSB...
# Saving 8EWS from RCSB...
# Downloading 8EXB from RCSB...
# Saving 8EXB from RCSB...
# Downloading 8SO1 from RCSB...
# Saving 8SO1 from RCSB...
# Downloading 8SO2 from RCSB...
# Saving 8SO2 from RCSB...
# Downloading 8SPD from RCSB...
# Saving 8SPD from RCSB...
# Downloading 9BBB from RCSB...
# Saving 9BBB from RCSB...
# Downloading 9BV5 from RCSB...
# Saving 9BV5 from RCSB...
# Downloading 9BV6 from RCSB...
# Saving 9BV6 from RCSB...
# Downloading 9BV7 from RCSB...
# Saving 9BV7 from RCSB...
# Downloading 9BV8 from RCSB...
# Saving 9BV8 from RCSB...
# Downloading 9BV9 from RCSB...
# Saving 9BV9 from RCSB...
# Downloading 9BVA from RCSB...
# Saving 9BVA from RCSB...
# Downloading 9BVB from RCSB...
# Saving 9BVB from RCSB...
# Downloading 9BVC from RCSB...
# Saving 9BVC from RCSB...
# Downloading 9COR from RCSB...
# Saving 9COR from RCSB...
# Downloading 9COS from RCSB...
# Saving 9COS from RCSB...
# Downloading 9COT from RCSB...
# Saving 9COT from RCSB...
# Downloading 9COU from RCSB...
# Saving 9COU from RCSB...
# Downloading 9COV from RCSB...
# Saving 9COV from RCSB...
# Downloading 9COW from RCSB...
# Saving 9COW from RCSB...
# Downloading 9COX from RCSB...
# Saving 9COX from RCSB...
# Downloading 9COY from RCSB...
# Saving 9COY from RCSB...
# Downloading 9GK1 from RCSB...
# Saving 9GK1 from RCSB...
# Downloading 9MS1 from RCSB...
# Saving 9MS1 from RCSB...
# Downloading 9PLJ from RCSB...
# Saving 9PLJ from RCSB...
# Downloading 9PLK from RCSB...
# Saving 9PLK from RCSB...
# Downloading 9YK4 from RCSB...
# Saving 9YK4 from RCSB...

# %%
# Download PDB
output='pdb_test'
for _id in pdb_ids:
    pdb_response = rut.get_rcsb_url(_id)
    try:
        pdb_text = rut.download_rcsb_file(_id, fmt='pdb', outdir=output)
    except ValueError:
        print(f"PDB not available for {_id}. Trying to download mmCIF and convert to PDB.")
        cif_text = rut.download_rcsb_file(_id, fmt='cif', outdir=output, get_text=True)
        pdb_text = rut.convert_cif_to_pdb_gemmi(cif_text)
        print(f"Saving {_id} PDB from mmCIF...")
        # Conversion function does not save file, so you must specify your direct path below
        with open(f"{output}/{_id}.pdb", "w") as f:
            f.write(pdb_text)
# Out:
# Downloading 1TQN from RCSB...
# Saving 1TQN from RCSB...
# Downloading 1W0E from RCSB...
# Saving 1W0E from RCSB...
# Downloading 1W0F from RCSB...
# Saving 1W0F from RCSB...
# Downloading 1W0G from RCSB...
# Saving 1W0G from RCSB...
# Downloading 2J0D from RCSB...
# Saving 2J0D from RCSB...
# Downloading 2V0M from RCSB...
# Saving 2V0M from RCSB...
# Downloading 3NXU from RCSB...
# Saving 3NXU from RCSB...
# Downloading 3TJS from RCSB...
# Saving 3TJS from RCSB...
# Downloading 3UA1 from RCSB...
# Saving 3UA1 from RCSB...
# Downloading 4D6Z from RCSB...
# Saving 4D6Z from RCSB...
# Downloading 4D75 from RCSB...
# Saving 4D75 from RCSB...
# Downloading 4D78 from RCSB...
# Saving 4D78 from RCSB...
# Downloading 4D7D from RCSB...
# Saving 4D7D from RCSB...
# Downloading 4I3Q from RCSB...
# Saving 4I3Q from RCSB...
# Downloading 4I4G from RCSB...
# Saving 4I4G from RCSB...
# Downloading 4I4H from RCSB...
# Saving 4I4H from RCSB...
# Downloading 4K9T from RCSB...
# Saving 4K9T from RCSB...
# Downloading 4K9U from RCSB...
# Saving 4K9U from RCSB...
# Downloading 4K9V from RCSB...
# Saving 4K9V from RCSB...
# Downloading 4K9W from RCSB...
# Saving 4K9W from RCSB...
# Downloading 4K9X from RCSB...
# Saving 4K9X from RCSB...
# Downloading 4NY4 from RCSB...
# Saving 4NY4 from RCSB...
# Downloading 5A1P from RCSB...
# Saving 5A1P from RCSB...
# Downloading 5A1R from RCSB...
# Saving 5A1R from RCSB...
# Downloading 5G5J from RCSB...
# Saving 5G5J from RCSB...
# Downloading 5TE8 from RCSB...
# Saving 5TE8 from RCSB...
# Downloading 5VC0 from RCSB...
# Saving 5VC0 from RCSB...
# Downloading 5VCC from RCSB...
# Saving 5VCC from RCSB...
# Downloading 5VCD from RCSB...
# Saving 5VCD from RCSB...
# Downloading 5VCE from RCSB...
# Saving 5VCE from RCSB...
# Downloading 5VCG from RCSB...
# Saving 5VCG from RCSB...
# Downloading 6BCZ from RCSB...
# Saving 6BCZ from RCSB...
# Downloading 6BD5 from RCSB...
# Saving 6BD5 from RCSB...
# Downloading 6BD6 from RCSB...
# Saving 6BD6 from RCSB...
# Downloading 6BD7 from RCSB...
# Saving 6BD7 from RCSB...
# Downloading 6BD8 from RCSB...
# Saving 6BD8 from RCSB...
# Downloading 6BDH from RCSB...
# Saving 6BDH from RCSB...
# Downloading 6BDI from RCSB...
# Saving 6BDI from RCSB...
# Downloading 6BDK from RCSB...
# Saving 6BDK from RCSB...
# Downloading 6BDM from RCSB...
# Saving 6BDM from RCSB...
# Downloading 6DA2 from RCSB...
# Saving 6DA2 from RCSB...
# Downloading 6DA3 from RCSB...
# Saving 6DA3 from RCSB...
# Downloading 6DA5 from RCSB...
# Saving 6DA5 from RCSB...
# Downloading 6DA8 from RCSB...
# Saving 6DA8 from RCSB...
# Downloading 6DAA from RCSB...
# Saving 6DAA from RCSB...
# Downloading 6DAB from RCSB...
# Saving 6DAB from RCSB...
# Downloading 6DAC from RCSB...
# Saving 6DAC from RCSB...
# Downloading 6DAG from RCSB...
# Saving 6DAG from RCSB...
# Downloading 6DAJ from RCSB...
# Saving 6DAJ from RCSB...
# Downloading 6DAL from RCSB...
# Saving 6DAL from RCSB...
# Downloading 6MA6 from RCSB...
# Saving 6MA6 from RCSB...
# Downloading 6MA7 from RCSB...
# Saving 6MA7 from RCSB...
# Downloading 6MA8 from RCSB...
# Saving 6MA8 from RCSB...
# Downloading 6OO9 from RCSB...
# Saving 6OO9 from RCSB...
# Downloading 6OOA from RCSB...
# Saving 6OOA from RCSB...
# Downloading 6OOB from RCSB...
# Saving 6OOB from RCSB...
# Downloading 6UNE from RCSB...
# Saving 6UNE from RCSB...
# Downloading 6UNG from RCSB...
# Saving 6UNG from RCSB...
# Downloading 6UNH from RCSB...
# Saving 6UNH from RCSB...
# Downloading 6UNI from RCSB...
# Saving 6UNI from RCSB...
# Downloading 6UNJ from RCSB...
# Saving 6UNJ from RCSB...
# Downloading 6UNK from RCSB...
# Saving 6UNK from RCSB...
# Downloading 6UNL from RCSB...
# Saving 6UNL from RCSB...
# Downloading 6UNM from RCSB...
# Saving 6UNM from RCSB...
# Downloading 7KS8 from RCSB...
# Saving 7KS8 from RCSB...
# Downloading 7KSA from RCSB...
# Saving 7KSA from RCSB...
# Downloading 7KVH from RCSB...
# Saving 7KVH from RCSB...
# Downloading 7KVI from RCSB...
# Saving 7KVI from RCSB...
# Downloading 7KVJ from RCSB...
# Saving 7KVJ from RCSB...
# Downloading 7KVK from RCSB...
# Saving 7KVK from RCSB...
# Downloading 7KVM from RCSB...
# Saving 7KVM from RCSB...
# Downloading 7KVN from RCSB...
# Saving 7KVN from RCSB...
# Downloading 7KVO from RCSB...
# Saving 7KVO from RCSB...
# Downloading 7KVP from RCSB...
# Saving 7KVP from RCSB...
# Downloading 7KVQ from RCSB...
# Saving 7KVQ from RCSB...
# Downloading 7KVS from RCSB...
# Saving 7KVS from RCSB...
# Downloading 7LXL from RCSB...
# Saving 7LXL from RCSB...
# Downloading 7UAY from RCSB...
# Saving 7UAY from RCSB...
# Downloading 7UAZ from RCSB...
# Saving 7UAZ from RCSB...
# Downloading 7UF9 from RCSB...
# Saving 7UF9 from RCSB...
# Downloading 7UFA from RCSB...
# Saving 7UFA from RCSB...
# Downloading 7UFB from RCSB...
# Saving 7UFB from RCSB...
# Downloading 7UFC from RCSB...
# Saving 7UFC from RCSB...
# Downloading 7UFD from RCSB...
# Saving 7UFD from RCSB...
# Downloading 7UFE from RCSB...
# Saving 7UFE from RCSB...
# Downloading 7UFF from RCSB...
# Saving 7UFF from RCSB...
# Downloading 8DYC from RCSB...
# Saving 8DYC from RCSB...
# Downloading 8EWD from RCSB...
# Saving 8EWD from RCSB...
# Downloading 8EWE from RCSB...
# Saving 8EWE from RCSB...
# Downloading 8EWL from RCSB...
# Saving 8EWL from RCSB...
# Downloading 8EWM from RCSB...
# Saving 8EWM from RCSB...
# Downloading 8EWN from RCSB...
# Saving 8EWN from RCSB...
# Downloading 8EWP from RCSB...
# Saving 8EWP from RCSB...
# Downloading 8EWQ from RCSB...
# Saving 8EWQ from RCSB...
# Downloading 8EWR from RCSB...
# Saving 8EWR from RCSB...
# Downloading 8EWS from RCSB...
# Saving 8EWS from RCSB...
# Downloading 8EXB from RCSB...
# Saving 8EXB from RCSB...
# Downloading 8SO1 from RCSB...
# Saving 8SO1 from RCSB...
# Downloading 8SO2 from RCSB...
# Saving 8SO2 from RCSB...
# Downloading 8SPD from RCSB...
# Saving 8SPD from RCSB...
# PDB not available for 9BBB. Trying to download mmCIF and convert to PDB.
# Downloading 9BBB from RCSB...
# Saving 9BBB from RCSB...
# Saving 9BBB PDB from mmCIF...
# PDB not available for 9BV5. Trying to download mmCIF and convert to PDB.
# Downloading 9BV5 from RCSB...
# Saving 9BV5 from RCSB...
# Saving 9BV5 PDB from mmCIF...
# PDB not available for 9BV6. Trying to download mmCIF and convert to PDB.
# Downloading 9BV6 from RCSB...
# Saving 9BV6 from RCSB...
# Saving 9BV6 PDB from mmCIF...
# PDB not available for 9BV7. Trying to download mmCIF and convert to PDB.
# Downloading 9BV7 from RCSB...
# Saving 9BV7 from RCSB...
# Saving 9BV7 PDB from mmCIF...
# PDB not available for 9BV8. Trying to download mmCIF and convert to PDB.
# Downloading 9BV8 from RCSB...
# Saving 9BV8 from RCSB...
# Saving 9BV8 PDB from mmCIF...
# PDB not available for 9BV9. Trying to download mmCIF and convert to PDB.
# Downloading 9BV9 from RCSB...
# Saving 9BV9 from RCSB...
# Saving 9BV9 PDB from mmCIF...
# PDB not available for 9BVA. Trying to download mmCIF and convert to PDB.
# Downloading 9BVA from RCSB...
# Saving 9BVA from RCSB...
# Saving 9BVA PDB from mmCIF...
# PDB not available for 9BVB. Trying to download mmCIF and convert to PDB.
# Downloading 9BVB from RCSB...
# Saving 9BVB from RCSB...
# Saving 9BVB PDB from mmCIF...
# PDB not available for 9BVC. Trying to download mmCIF and convert to PDB.
# Downloading 9BVC from RCSB...
# Saving 9BVC from RCSB...
# Saving 9BVC PDB from mmCIF...
# PDB not available for 9COR. Trying to download mmCIF and convert to PDB.
# Downloading 9COR from RCSB...
# Saving 9COR from RCSB...
# Saving 9COR PDB from mmCIF...
# PDB not available for 9COS. Trying to download mmCIF and convert to PDB.
# Downloading 9COS from RCSB...
# Saving 9COS from RCSB...
# Saving 9COS PDB from mmCIF...
# PDB not available for 9COT. Trying to download mmCIF and convert to PDB.
# Downloading 9COT from RCSB...
# Saving 9COT from RCSB...
# Saving 9COT PDB from mmCIF...
# PDB not available for 9COU. Trying to download mmCIF and convert to PDB.
# Downloading 9COU from RCSB...
# Saving 9COU from RCSB...
# Saving 9COU PDB from mmCIF...
# PDB not available for 9COV. Trying to download mmCIF and convert to PDB.
# Downloading 9COV from RCSB...
# Saving 9COV from RCSB...
# Saving 9COV PDB from mmCIF...
# PDB not available for 9COW. Trying to download mmCIF and convert to PDB.
# Downloading 9COW from RCSB...
# Saving 9COW from RCSB...
# Saving 9COW PDB from mmCIF...
# PDB not available for 9COX. Trying to download mmCIF and convert to PDB.
# Downloading 9COX from RCSB...
# Saving 9COX from RCSB...
# Saving 9COX PDB from mmCIF...
# PDB not available for 9COY. Trying to download mmCIF and convert to PDB.
# Downloading 9COY from RCSB...
# Saving 9COY from RCSB...
# Saving 9COY PDB from mmCIF...
# Downloading 9GK1 from RCSB...
# Saving 9GK1 from RCSB...
# PDB not available for 9MS1. Trying to download mmCIF and convert to PDB.
# Downloading 9MS1 from RCSB...
# Saving 9MS1 from RCSB...
# Saving 9MS1 PDB from mmCIF...
# Downloading 9PLJ from RCSB...
# Saving 9PLJ from RCSB...
# PDB not available for 9PLK. Trying to download mmCIF and convert to PDB.
# Downloading 9PLK from RCSB...
# Saving 9PLK from RCSB...
# Saving 9PLK PDB from mmCIF...
# Downloading 9YK4 from RCSB...
# Saving 9YK4 from RCSB...
