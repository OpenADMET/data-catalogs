# %%
import pandas as pd
from download_cif import download_cif_files, get_pdb_ids

# %%
df = pd.read_csv("uniprot_ids.csv")

# %%
df
# Out:
#      Name UniProt ID
# 0     AHR     P35869
# 1     PXR     O75469
# 2  CYP1A2     P05177
# 3  CYP2D6     P10635
# 4  CYP3A4     P08684
# 5  CYP2C9     P11712

# %%
len(get_pdb_ids("O75469"))
# Out:
# 80

# %%
for dirname,uniprot in df.values:
    download_cif_files(dirname,uniprot)
# Out:
# Found 3 PDB IDs for UniProt ID: P35869
# File already exists: AHR/5NJ8.cif
# File already exists: AHR/7ZUB.cif
# File already exists: AHR/8QMO.cif
# Found 80 PDB IDs for UniProt ID: O75469
# File already exists: PXR/1ILG.cif
# File already exists: PXR/1ILH.cif
# File already exists: PXR/1M13.cif
# File already exists: PXR/1NRL.cif
# File already exists: PXR/1SKX.cif
# File already exists: PXR/2O9I.cif
# File already exists: PXR/2QNV.cif
# File already exists: PXR/3CTB.cif
# File already exists: PXR/3HVL.cif
# File already exists: PXR/3R8D.cif
# ...
# Found 1 PDB IDs for UniProt ID: P05177
# File already exists: CYP1A2/2HI4.cif
# Found 14 PDB IDs for UniProt ID: P10635
# File already exists: CYP2D6/2F9Q.cif
# File already exists: CYP2D6/3QM4.cif
# File already exists: CYP2D6/3TBG.cif
# File already exists: CYP2D6/3TDA.cif
# File already exists: CYP2D6/4WNT.cif
# File already exists: CYP2D6/4WNU.cif
# File already exists: CYP2D6/4WNV.cif
# File already exists: CYP2D6/4WNW.cif
# ...

# %%
# !ls
# Out:
# AHR	CYP2D6			  download_cif.py	      __pycache__
# CYP1A2	CYP3A4			  download_process_pdb.ipynb  uniprot_ids.csv
# CYP2C9	download_CIF_files.ipynb  PXR
