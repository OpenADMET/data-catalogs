# %%
from openadmet.toolkit.chemoinformatics.data_curation import DataProcessing
import os
import pandas as pd
import numpy as np

# %%
file = "./processed/PXR/processed_AID_1347033_datatable.parquet"

df = DataProcessing.read_file(file)
df
# Out:
#      PUBCHEM_RESULT_TAG  PUBCHEM_SID PUBCHEM_CID  \
# 0                     1  170465705.0     10219.0
# 1                     2  170465704.0   6708701.0
# 2                     3  144214002.0      7594.0
# 3                     4  144206912.0    156414.0
# 4                     5  144213201.0   5280443.0
# ...                 ...          ...         ...
# 9473               9663  251919825.0      1127.0
# 9474               9664  251919641.0    104856.0
# 9475               9665  251919683.0    104556.0
# 9476               9666  251919642.0     47289.0
# 9477               9667  251919673.0      9131.0
#
#                           PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0     CC[C@H]1CN2CCC3=CC(=C(C=C3[C@@H]2C[C@@H]1C[C@@...
# 1                    C[C@]12C3CCC([C@]1(C(=O)OC2=O)C)O3
# 2                       C1=CC=C(C=C1)NC(=NC2=CC=CC=C2)N
# 3     C=CC(=O)NC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC(=C(C=C...
# 4            C1=CC(=CC=C1C2=CC(=O)C3=C(C=C(C=C3O2)O)O)O
# ...                                                 ...
# 9473                                            C1CCSC1
# 9474                          CN(CCCC(C1=CN=CC=C1)O)N=O
# 9475                              C1N(CN(CN1CCO)CCO)CCO
# 9476                         CN(CCCC(=O)C1=CN=CC=C1)N=O
# 9477  C1=CC=C2C(=C1)C3=C4C2=CC5=CC=CC6=C5C4=C(C=C6)C=C3
#
#      PUBCHEM_ACTIVITY_OUTCOME PUBCHEM_ACTIVITY_SCORE PUBCHEM_ACTIVITY_URL  \
# 0                      Active                  100.0                  nan
# 1                      Active                   99.0                  nan
# 2                      Active                   93.0                  nan
# 3                      Active                   91.0                  nan
# 4                      Active                   90.0                  nan
# ...                       ...                    ...                  ...
# 9473                 Inactive                    0.0                  nan
# 9474                 Inactive                    0.0                  nan
# 9475                 Inactive                    0.0                  nan
# 9476                 Inactive                    0.0                  nan
# 9477                 Inactive                    0.0                  nan
#
#      PUBCHEM_ASSAYDATA_COMMENT Activity Summary Agonist Activity  \
# 0                          nan   active agonist   active agonist
# 1                          nan   active agonist   active agonist
# 2                          nan   active agonist   active agonist
# 3                          nan   active agonist   active agonist
# 4                          nan   active agonist   active agonist
# ...                        ...              ...              ...
# 9473                       nan         inactive         inactive
# 9474                       nan         inactive         inactive
# 9475                       nan         inactive         inactive
# 9476                       nan         inactive         inactive
# 9477                       nan         inactive         inactive
#
#      Agonist Potency (uM) Agonist Efficacy (%) Viability Activity  \
# 0              0.03349146          211.4194337  active antagonist
# 1              1.01921876          362.3484966  active antagonist
# 2              4.86743404          489.9294473  active antagonist
# 3             11.00527102           655.906322  active antagonist
# 4             22.53850342          949.4401877  active antagonist
# ...                   ...                  ...                ...
# 9473                  nan                    0           inactive
# 9474                  nan                    0           inactive
# 9475                  nan                    0           inactive
# 9476                  nan                    0           inactive
# 9477                  nan                    0           inactive
#
#      Viability Potency (uM) Viability Efficacy (%)  \
# 0                  0.037578               -58.1492
# 1                  0.237101               -73.1631
# 2                    5.6492               -54.6079
# 3                   2.87255               -44.3797
# 4                   27.5955               -72.5478
# ...                     ...                    ...
# 9473                    nan                      0
# 9474                    nan                      0
# 9475                    nan                      0
# 9476                    nan                      0
# 9477                    nan                      0
#
#                          Sample Source  \
# 0                                 Enzo
# 1                                 Enzo
# 2                                SIGMA
# 3                              Selleck
# 4                     LightBiologicals
# ...                                ...
# 9473                       TCI America
# 9474  Toronto Research Chemicals, Inc.
# 9475  Toronto Research Chemicals, Inc.
# 9476  Toronto Research Chemicals, Inc.
# 9477  Toronto Research Chemicals, Inc.
#
#                              OPENADMET_CANONICAL_SMILES  \
# 0     CC[C@H]1CN2CCC3=CC(OC)=C(OC)C=C3[C@@H]2C[C@@H]...
# 1                   C[C@@]12C(=O)OC(=O)[C@]1(C)C1CCC2O1
# 2                         N=C(NC1=CC=CC=C1)NC1=CC=CC=C1
# 3     C=CC(=O)NC1=CC2=C(NC3=CC=C(F)C(Cl)=C3)N=CN=C2C...
# 4            O=C1C=C(C2=CC=C(O)C=C2)OC2=CC(O)=CC(O)=C12
# ...                                                 ...
# 9473                                            C1CCSC1
# 9474                          CN(CCCC(O)C1=CC=CN=C1)N=O
# 9475                              OCCN1CN(CCO)CN(CCO)C1
# 9476                         CN(CCCC(=O)C1=CC=CN=C1)N=O
# 9477    C1=CC=C2C(=C1)C1=CC=C3C=CC4=CC=CC5=CC2=C1C3=C45
#
#                          INCHIKEY
# 0     AUVVAXYIELKVAI-CKBKHPSWSA-N
# 1     DHZBEENLJMYSHQ-OBDNUKKESA-N
# 2     OWRCNXZUPFZXOS-UHFFFAOYSA-N
# 3     OMZCMEYTWSXEPZ-UHFFFAOYSA-N
# 4     KZNIFHPLKGYRTM-UHFFFAOYSA-N
# ...                           ...
# 9473  RAOIDOHSFRTOEL-UHFFFAOYSA-N
# 9474  OGRXKBUCZFFSTL-UHFFFAOYSA-N
# 9475  HUHGPYXAVBJSJV-UHFFFAOYSA-N
# 9476  FLAQQSHRLBFIEZ-UHFFFAOYSA-N
# 9477  SXQBHARYMNFBPS-UHFFFAOYSA-N
#
# [9478 rows x 18 columns]

# %%
processor = DataProcessing()
# data = processor.standardize_smiles_and_convert(data=df)
# data

# %%
df.columns
# Out:
# Index(['PUBCHEM_RESULT_TAG', 'PUBCHEM_SID', 'PUBCHEM_CID',
#        'PUBCHEM_EXT_DATASOURCE_SMILES', 'PUBCHEM_ACTIVITY_OUTCOME',
#        'PUBCHEM_ACTIVITY_SCORE', 'PUBCHEM_ACTIVITY_URL',
#        'PUBCHEM_ASSAYDATA_COMMENT', 'Activity Summary', 'Agonist Activity',
#        'Agonist Potency (uM)', 'Agonist Efficacy (%)', 'Viability Activity',
#        'Viability Potency (uM)', 'Viability Efficacy (%)', 'Sample Source',
#        'OPENADMET_CANONICAL_SMILES', 'INCHIKEY'],
#       dtype='object')

# %%
data = processor.get_pac50(data=df, pac50_col='Agonist Potency (uM)', input_unit="uM", activity_type="EC50")
data
# Out:
#      PUBCHEM_RESULT_TAG  PUBCHEM_SID PUBCHEM_CID  \
# 0                     1  170465705.0     10219.0
# 1                     2  170465704.0   6708701.0
# 2                     3  144214002.0      7594.0
# 3                     4  144206912.0    156414.0
# 4                     5  144213201.0   5280443.0
# ...                 ...          ...         ...
# 9473               9663  251919825.0      1127.0
# 9474               9664  251919641.0    104856.0
# 9475               9665  251919683.0    104556.0
# 9476               9666  251919642.0     47289.0
# 9477               9667  251919673.0      9131.0
#
#                           PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0     CC[C@H]1CN2CCC3=CC(=C(C=C3[C@@H]2C[C@@H]1C[C@@...
# 1                    C[C@]12C3CCC([C@]1(C(=O)OC2=O)C)O3
# 2                       C1=CC=C(C=C1)NC(=NC2=CC=CC=C2)N
# 3     C=CC(=O)NC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC(=C(C=C...
# 4            C1=CC(=CC=C1C2=CC(=O)C3=C(C=C(C=C3O2)O)O)O
# ...                                                 ...
# 9473                                            C1CCSC1
# 9474                          CN(CCCC(C1=CN=CC=C1)O)N=O
# 9475                              C1N(CN(CN1CCO)CCO)CCO
# 9476                         CN(CCCC(=O)C1=CN=CC=C1)N=O
# 9477  C1=CC=C2C(=C1)C3=C4C2=CC5=CC=CC6=C5C4=C(C=C6)C=C3
#
#      PUBCHEM_ACTIVITY_OUTCOME PUBCHEM_ACTIVITY_SCORE PUBCHEM_ACTIVITY_URL  \
# 0                      Active                  100.0                  nan
# 1                      Active                   99.0                  nan
# 2                      Active                   93.0                  nan
# 3                      Active                   91.0                  nan
# 4                      Active                   90.0                  nan
# ...                       ...                    ...                  ...
# 9473                 Inactive                    0.0                  nan
# 9474                 Inactive                    0.0                  nan
# 9475                 Inactive                    0.0                  nan
# 9476                 Inactive                    0.0                  nan
# 9477                 Inactive                    0.0                  nan
#
#      PUBCHEM_ASSAYDATA_COMMENT Activity Summary Agonist Activity  \
# 0                          nan   active agonist   active agonist
# 1                          nan   active agonist   active agonist
# 2                          nan   active agonist   active agonist
# 3                          nan   active agonist   active agonist
# 4                          nan   active agonist   active agonist
# ...                        ...              ...              ...
# 9473                       nan         inactive         inactive
# 9474                       nan         inactive         inactive
# 9475                       nan         inactive         inactive
# 9476                       nan         inactive         inactive
# 9477                       nan         inactive         inactive
#
#      Agonist Potency (uM) Agonist Efficacy (%) Viability Activity  \
# 0              0.03349146          211.4194337  active antagonist
# 1              1.01921876          362.3484966  active antagonist
# 2              4.86743404          489.9294473  active antagonist
# 3             11.00527102           655.906322  active antagonist
# 4             22.53850342          949.4401877  active antagonist
# ...                   ...                  ...                ...
# 9473                  nan                    0           inactive
# 9474                  nan                    0           inactive
# 9475                  nan                    0           inactive
# 9476                  nan                    0           inactive
# 9477                  nan                    0           inactive
#
#      Viability Potency (uM) Viability Efficacy (%)  \
# 0                  0.037578               -58.1492
# 1                  0.237101               -73.1631
# 2                    5.6492               -54.6079
# 3                   2.87255               -44.3797
# 4                   27.5955               -72.5478
# ...                     ...                    ...
# 9473                    nan                      0
# 9474                    nan                      0
# 9475                    nan                      0
# 9476                    nan                      0
# 9477                    nan                      0
#
#                          Sample Source  \
# 0                                 Enzo
# 1                                 Enzo
# 2                                SIGMA
# 3                              Selleck
# 4                     LightBiologicals
# ...                                ...
# 9473                       TCI America
# 9474  Toronto Research Chemicals, Inc.
# 9475  Toronto Research Chemicals, Inc.
# 9476  Toronto Research Chemicals, Inc.
# 9477  Toronto Research Chemicals, Inc.
#
#                              OPENADMET_CANONICAL_SMILES  \
# 0     CC[C@H]1CN2CCC3=CC(OC)=C(OC)C=C3[C@@H]2C[C@@H]...
# 1                   C[C@@]12C(=O)OC(=O)[C@]1(C)C1CCC2O1
# 2                         N=C(NC1=CC=CC=C1)NC1=CC=CC=C1
# 3     C=CC(=O)NC1=CC2=C(NC3=CC=C(F)C(Cl)=C3)N=CN=C2C...
# 4            O=C1C=C(C2=CC=C(O)C=C2)OC2=CC(O)=CC(O)=C12
# ...                                                 ...
# 9473                                            C1CCSC1
# 9474                          CN(CCCC(O)C1=CC=CN=C1)N=O
# 9475                              OCCN1CN(CCO)CN(CCO)C1
# 9476                         CN(CCCC(=O)C1=CC=CN=C1)N=O
# 9477    C1=CC=C2C(=C1)C1=CC=C3C=CC4=CC=CC5=CC2=C1C3=C45
#
#                          INCHIKEY  OPENADMET_LOGAC50 OPENADMET_ACTIVITY_TYPE
# 0     AUVVAXYIELKVAI-CKBKHPSWSA-N           7.475066                   pEC50
# 1     DHZBEENLJMYSHQ-OBDNUKKESA-N           5.991733                   pEC50
# 2     OWRCNXZUPFZXOS-UHFFFAOYSA-N           5.312700                   pEC50
# 3     OMZCMEYTWSXEPZ-UHFFFAOYSA-N           4.958399                   pEC50
# 4     KZNIFHPLKGYRTM-UHFFFAOYSA-N           4.647075                   pEC50
# ...                           ...                ...                     ...
# 9473  RAOIDOHSFRTOEL-UHFFFAOYSA-N                NaN                   pEC50
# 9474  OGRXKBUCZFFSTL-UHFFFAOYSA-N                NaN                   pEC50
# 9475  HUHGPYXAVBJSJV-UHFFFAOYSA-N                NaN                   pEC50
# 9476  FLAQQSHRLBFIEZ-UHFFFAOYSA-N                NaN                   pEC50
# 9477  SXQBHARYMNFBPS-UHFFFAOYSA-N                NaN                   pEC50
#
# [9478 rows x 20 columns]

# %%
data.to_parquet("./final/cleaned_summary_PXR.parquet", index=False)
