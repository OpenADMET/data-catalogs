# %%
import pandas as pd

# %%
pd.read_parquet("./ChEMBL35_permissive_2025-04-02/ChEMBL_permissive_AHR_CHEMBL3201_aggregated.parquet")
# Out:
#                                       OPENADMET_SMILES  \
# 39              CC1=CC(Cl)=CC2=C1OC1=CC(Cl)=CC(Cl)=C12
# 252          O=C1C=C(C2=CC=CC=C2)OC2=CC=C3C=CC=CC3=C12
# 99            CNC(=O)C1=CSC(C(=O)C2=CNC3=CC=CC=C23)=N1
# 261         O=CC1=C2NC3=CC=CC=C3C2=CC2=C1C1=CC=CC=C1N2
# 251      O=C1C=C(C2=C(F)C=CC=C2F)OC2=CC=C3C=CC=CC3=C12
# ..                                                 ...
# 96         CN1C=C(CC2=C(C=O)C3=CC=CC=C3N2)C2=CC=CC=C21
# 95     CN1C2=CC=CC=C2C2=CC3=C(C(C=O)=C21)C1=CC=CC=C1N3
# 93                  CN1C(N)=C(C(=O)NC2=CC=CC=C2F)SC1=S
# 92       CN1C(C(=O)N2CCC(C(N)=O)CC2)=CC2=CC(Cl)=CC=C21
# 102  COC1=CC(/C=N/NC(=O)C2=CC=CC(NC(=O)C3=CC=CC=C3)...
#
#               OPENADMET_INCHIKEY  assay_id_count  standard_value_mean  \
# 39   RPMARRQIRRJWEZ-UHFFFAOYSA-N               4            24.565000
# 252  OUGIDAPQYNCXRA-UHFFFAOYSA-N               4          1052.100000
# 99   GOVAEEIQDCTMOG-UHFFFAOYSA-N               3            30.400000
# ...

# %%
pd.read_parquet("./ChEMBL34_permissive_2025-02-12/ChEMBL_permissive_AHR_CHEMBL3201_aggregated.parquet")
# Out:
#                                       OPENADMET_SMILES  \
# 39              CC1=CC(Cl)=CC2=C1OC1=CC(Cl)=CC(Cl)=C12
# 252          O=C1C=C(C2=CC=CC=C2)OC2=CC=C3C=CC=CC3=C12
# 99            CNC(=O)C1=CSC(C(=O)C2=CNC3=CC=CC=C23)=N1
# 261         O=CC1=C2NC3=CC=CC=C3C2=CC2=C1C1=CC=CC=C1N2
# 251      O=C1C=C(C2=C(F)C=CC=C2F)OC2=CC=C3C=CC=CC3=C12
# ..                                                 ...
# 96         CN1C=C(CC2=C(C=O)C3=CC=CC=C3N2)C2=CC=CC=C21
# 95     CN1C2=CC=CC=C2C2=CC3=C(C(C=O)=C21)C1=CC=CC=C1N3
# 93                  CN1C(N)=C(C(=O)NC2=CC=CC=C2F)SC1=S
# 92       CN1C(C(=O)N2CCC(C(N)=O)CC2)=CC2=CC(Cl)=CC=C21
# 102  COC1=CC(/C=N/NC(=O)C2=CC=CC(NC(=O)C3=CC=CC=C3)...
#
#               OPENADMET_INCHIKEY  assay_id_count  standard_value_mean  \
# 39   RPMARRQIRRJWEZ-UHFFFAOYSA-N               4            24.565000
# 252  OUGIDAPQYNCXRA-UHFFFAOYSA-N               4          1052.100000
# 99   GOVAEEIQDCTMOG-UHFFFAOYSA-N               3            30.400000
# ...

# %%
pd.read_parquet("./ChEMBL34_permissive_2025-02-12/ChEMBL_permissive_AHR_CHEMBL3201_raw.parquet")
# Out:
#      assay_id  doc_id  standard_value  molregno  \
# 0      688230   51887       3777.0000    685753
# 1     2289550  125708          0.2000    712090
# 2      688230   51887       2208.0000    724499
# 3      688230   51887       7434.0000    727000
# 4      688230   51887       7752.0000    727822
# ..        ...     ...             ...       ...
# 305   2292018  125776          0.0971   2805679
# 306   2289558  125708      12000.0000   2806910
# 307   2289549  125708          0.0100   2809401
# 308   1706516  106087       1500.0000   2245470
# 309   2289563  125708        127.0000   2341092
#
#                                       canonical_smiles    tid  \
# 0                    COc1ccc(NC(=O)c2ccc(C)cc2)c(OC)c1  10694
# 1                    O=C1Nc2ccccc2/C1=C1/Nc2ccccc2C1=O  10694
# 2                      CCOc1ccccc1NC(=O)c1ccc2nccnc2c1  10694
# 3                               CCOC(=O)c1oc2ccccc2c1N  10694
# 4    Cc1ccc(-n2c(=O)[nH]cc(C(=O)Nc3ccc4c(c3)OCO4)c2...  10694
# ...

# %%
pd.read_parquet("./ChEMBL34_permissive_2025-02-12/ChEMBL_permissive_PXR_CHEMBL3401_aggregated.parquet")
# Out:
#                                       OPENADMET_SMILES  \
# 659  CO[C@H]1/C=C/O[C@@]2(C)OC3=C(C)C(O)=C4C(O)=C(N...
# 853  O=S(=O)(C1=CC=CC=C1)N(CC(F)(F)F)C1=CC=C(C(O)(C...
# 829  O=C1NC2=CC=CC=C2N1CCCN1CCN(C(C2=CC=CC=C2)C2=CC...
# 504  COC1=CC(C(=O)NS(=O)(=O)C2=CC=CC=C2C)=CC=C1CC1=...
# 473  COC(=O)C1=C(C#N)N=C(C)C(C(=O)OC(C)C)C1C1=CC=CC...
# ..                                                 ...
# 12   C/C(=C\C1=CC=C2O[C@@H](CCC(=O)O)CN(S(=O)(=O)C3...
# 13   C/C(=C\C1=CC=C2O[C@@H](CCC(=O)O)CN(S(=O)(=O)C3...
# 47   CC(=O)N1CCC(C)(C(=O)N2CC[C@](C3=CC=C(C(OCC4=C(...
# 48   CC(=O)N1CCC(C2=CC=C(C(O)(C(F)(F)F)C(F)(F)F)C=C...
# 50   CC(=O)N1CCN(C(=O)N2CC[C@](C3=CC=C(C(OCC4=C(F)C...
#
#               OPENADMET_INCHIKEY  assay_id_count  standard_value_mean  \
# 659  JQXXHWHPUNPDRT-WLSIYKJHSA-N              13          3228.892308
# 853  SGIWFELWJPNFDH-UHFFFAOYSA-N              11            59.036364
# 829  BAINIUMDFURPJM-UHFFFAOYSA-N               6          4000.000000
# ...

# %%
pd.read_parquet("./ChEMBL35_permissive_2025-04-02/ChEMBL_permissive_PXR_CHEMBL3401_aggregated.parquet")
# Out:
#                                       OPENADMET_SMILES  \
# 659  CO[C@H]1/C=C/O[C@@]2(C)OC3=C(C)C(O)=C4C(O)=C(N...
# 853  O=S(=O)(C1=CC=CC=C1)N(CC(F)(F)F)C1=CC=C(C(O)(C...
# 829  O=C1NC2=CC=CC=C2N1CCCN1CCN(C(C2=CC=CC=C2)C2=CC...
# 504  COC1=CC(C(=O)NS(=O)(=O)C2=CC=CC=C2C)=CC=C1CC1=...
# 473  COC(=O)C1=C(C#N)N=C(C)C(C(=O)OC(C)C)C1C1=CC=CC...
# ..                                                 ...
# 12   C/C(=C\C1=CC=C2O[C@@H](CCC(=O)O)CN(S(=O)(=O)C3...
# 13   C/C(=C\C1=CC=C2O[C@@H](CCC(=O)O)CN(S(=O)(=O)C3...
# 47   CC(=O)N1CCC(C)(C(=O)N2CC[C@](C3=CC=C(C(OCC4=C(...
# 48   CC(=O)N1CCC(C2=CC=C(C(O)(C(F)(F)F)C(F)(F)F)C=C...
# 50   CC(=O)N1CCN(C(=O)N2CC[C@](C3=CC=C(C(OCC4=C(F)C...
#
#               OPENADMET_INCHIKEY  assay_id_count  standard_value_mean  \
# 659  JQXXHWHPUNPDRT-WLSIYKJHSA-N              13          3228.892308
# 853  SGIWFELWJPNFDH-UHFFFAOYSA-N              11            59.036364
# 829  BAINIUMDFURPJM-UHFFFAOYSA-N               6          4000.000000
# ...
